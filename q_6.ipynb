# %% [markdown]
# <a href="https://colab.research.google.com/github/Adithyan-mp/Image_Processing/blob/main/q_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread('/content/930039-1920x1080-desktop-full-hd-monkey-d-luffy-wallpaper-photo.jpg')
rows, cols = img.shape[:2]

# --- 1. Translation ---
M_translate = np.float32([[1, 0, 50], [0, 1, 30]])
translated_img = cv2.warpAffine(img, M_translate, (cols, rows))

# --- 2. Rotation ---
M_rotate = cv2.getRotationMatrix2D((cols / 2, rows / 2), 45, 1.0)
rotated_img = cv2.warpAffine(img, M_rotate, (cols, rows))

# --- 3. Scaling ---
scaled_img = cv2.resize(img, None, fx=1.5, fy=1.5, interpolation=cv2.INTER_LINEAR)

# --- 4. Skewing  ---
pts1 = np.float32([[50, 50], [200, 50], [50, 200]])
pts2 = np.float32([[10, 100], [200, 50], [100, 250]])
M_skew = cv2.getAffineTransform(pts1, pts2)
skewed_img = cv2.warpAffine(img, M_skew, (cols, rows))

titles = ['Original', 'Translated', 'Rotated', 'Scaled', 'Skewed']
images = [img, translated_img, rotated_img, scaled_img, skewed_img]

plt.figure(figsize=(15, 8))
for i in range(5):
    plt.subplot(2, 3, i + 1)
    plt.imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB))
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()
